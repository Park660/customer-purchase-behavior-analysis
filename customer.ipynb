# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_excel('Customer Purchase Behavior datasets.xlsx')

# %%
df
# Out:
#                                Customer_ID   Age  Gender    Income Location  \
# 0     9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female  114415.0     City
# 1     ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male  160508.0     City
# 2     9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female   37669.0     City
# 3     4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male  147385.0     City
# 4     18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   92010.0   Suburb
# ...                                    ...   ...     ...       ...      ...
# 4995  5a1938c8-6983-49cb-bc15-abb5139fc5ba  24.0  Female   78465.0     City
# 4996  a1ebd1a8-0028-4e14-a11c-b72d57ec8485  66.0  Female  167745.0     City
# 4997  f4e8d429-f947-4340-9797-2199cb82e5ed  26.0    Male   43395.0     City
# 4998  7e8e9dab-a7af-4e1a-9401-eef18b57772b  53.0  Female  124162.0     City
# 4999  12437469-887f-40d4-9bd0-d399bd8f77db  36.0  Female  150704.0   Suburb
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer_ID                    5000 non-null   object
#  1   Age                            4997 non-null   float64
#  2   Gender                         4995 non-null   object
#  3   Income                         4996 non-null   float64
#  4   Location                       4996 non-null   object
#  5   Customer_Segment               4997 non-null   object
#  6   Transaction_ID                 5000 non-null   object
#  7   Date                           5000 non-null   datetime64[ns]
#  8   Product_Category               5000 non-null   object
#  9   Product_ID                     5000 non-null   object
#  10  Quantity                       5000 non-null   int64
#  11  Unit_Price                     5000 non-null   float64
# ...

# %%
df.describe()
# Out:
#                Age         Income                           Date     Quantity  \
# count  4997.000000    4996.000000                           5000  5000.000000
# mean     43.589954  108251.229384  2024-03-10 19:20:30.419999744     2.500600
# min      18.000000   20005.000000            2023-03-13 03:00:00     1.000000
# 25%      31.000000   62912.000000            2023-09-06 18:50:45     1.000000
# 50%      43.000000  107605.000000            2024-03-13 01:00:30     3.000000
# 75%      56.000000  153708.750000            2024-09-08 22:39:15     3.000000
# max      69.000000  199992.000000            2025-03-11 22:58:00     4.000000
# std      14.921685   52111.502273                            NaN     1.115638
#
#         Unit_Price  Total_Spent  Loyalty_Points_Used  Previous_Purchases  \
# count  5000.000000  5000.000000          5000.000000         5000.000000
# mean    253.622340   634.181692           246.914800           24.909200
# ...

# %%
df.isnull()
# Out:
#       Customer_ID    Age  Gender  Income  Location  Customer_Segment  \
# 0           False  False   False   False     False             False
# 1           False  False   False   False     False             False
# 2           False  False   False   False     False             False
# 3           False   True   False   False     False             False
# 4           False  False   False   False     False             False
# ...           ...    ...     ...     ...       ...               ...
# 4995        False  False   False   False     False             False
# 4996        False  False   False   False     False             False
# 4997        False  False   False   False     False             False
# 4998        False  False   False   False     False             False
# 4999        False  False   False   False     False             False
#
#       Transaction_ID   Date  Product_Category  Product_ID  ...  Total_Spent  \
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID                      0
# Age                              3
# Gender                           5
# Income                           4
# Location                         4
# Customer_Segment                 3
# Transaction_ID                   0
# Date                             0
# Product_Category                 0
# Product_ID                       0
# Quantity                         0
# Unit_Price                       0
# Total_Spent                      0
# Payment_Method                   0
# Discount_Applied                 0
# Loyalty_Points_Used              0
# Previous_Purchases               0
# Average_Spending                 0
# Last_Purchase_Days_Ago           0
# Browsing_Time_Before_Purchase    0
# Preferred_Shopping_Time          0
# Customer_Satisfaction_Rating     0
# dtype: int64

# %%
df['Age'].unique()
# Out:
# array([56., 69., 46., nan, 60., 25., 38., 36., 40., 28., 41., 53., 57.,
#        20., 39., 19., 61., 47., 55., 50., 29., 42., 66., 44., 59., 45.,
#        33., 64., 68., 54., 24., 26., 35., 21., 31., 67., 43., 37., 52.,
#        34., 23., 51., 27., 48., 65., 32., 62., 58., 18., 22., 30., 49.,
#        63.])

# %%
df['Income'].unique()
# Out:
# array([114415., 160508.,  37669., ...,  43395., 124162., 150704.],
#       shape=(4924,))

# %%
df['Customer_Segment'].unique()
# Out:
# array(['High', 'Medium', 'Low', nan], dtype=object)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                                Customer_ID   Age  Gender    Income Location  \
# 0     9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female  114415.0     City
# 1     ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male  160508.0     City
# 2     9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female   37669.0     City
# 3     4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male  147385.0     City
# 4     18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   92010.0   Suburb
# ...                                    ...   ...     ...       ...      ...
# 4995  5a1938c8-6983-49cb-bc15-abb5139fc5ba  24.0  Female   78465.0     City
# 4996  a1ebd1a8-0028-4e14-a11c-b72d57ec8485  66.0  Female  167745.0     City
# 4997  f4e8d429-f947-4340-9797-2199cb82e5ed  26.0    Male   43395.0     City
# 4998  7e8e9dab-a7af-4e1a-9401-eef18b57772b  53.0  Female  124162.0     City
# 4999  12437469-887f-40d4-9bd0-d399bd8f77db  36.0  Female  150704.0   Suburb
#
# ...

# %%
df.columns=df.columns.str.lower()

# %%
df
# Out:
#                                customer_id   age  gender    income location  \
# 0     9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female  114415.0     City
# 1     ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male  160508.0     City
# 2     9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female   37669.0     City
# 3     4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male  147385.0     City
# 4     18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   92010.0   Suburb
# ...                                    ...   ...     ...       ...      ...
# 4995  5a1938c8-6983-49cb-bc15-abb5139fc5ba  24.0  Female   78465.0     City
# 4996  a1ebd1a8-0028-4e14-a11c-b72d57ec8485  66.0  Female  167745.0     City
# 4997  f4e8d429-f947-4340-9797-2199cb82e5ed  26.0    Male   43395.0     City
# 4998  7e8e9dab-a7af-4e1a-9401-eef18b57772b  53.0  Female  124162.0     City
# 4999  12437469-887f-40d4-9bd0-d399bd8f77db  36.0  Female  150704.0   Suburb
#
# ...

# %%
df=df.drop(columns=['income'],inplace=True)

# %%
df

# %%
df

# %%
df['total_spent']=pd.to_numeric(df['total_spent'])

# %%
df
# Out:
#                                customer_id   age  gender location  \
# 0     9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female     City
# 1     ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male     City
# 2     9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female     City
# 3     4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male     City
# 4     18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   Suburb
# ...                                    ...   ...     ...      ...
# 4995  5a1938c8-6983-49cb-bc15-abb5139fc5ba  24.0  Female     City
# 4996  a1ebd1a8-0028-4e14-a11c-b72d57ec8485  66.0  Female     City
# 4997  f4e8d429-f947-4340-9797-2199cb82e5ed  26.0    Male     City
# 4998  7e8e9dab-a7af-4e1a-9401-eef18b57772b  53.0  Female     City
# 4999  12437469-887f-40d4-9bd0-d399bd8f77db  36.0  Female   Suburb
#
#      customer_segment                        transaction_id  \
# 0                High  d66461e5-ec3e-45c2-9975-2730e05b2613
# ...

# %%
df['purchase_month']=df['date'].dt.month

# %%
df
# Out:
#                                customer_id   age  gender location  \
# 0     9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female     City
# 1     ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male     City
# 2     9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female     City
# 3     4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male     City
# 4     18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   Suburb
# ...                                    ...   ...     ...      ...
# 4995  5a1938c8-6983-49cb-bc15-abb5139fc5ba  24.0  Female     City
# 4996  a1ebd1a8-0028-4e14-a11c-b72d57ec8485  66.0  Female     City
# 4997  f4e8d429-f947-4340-9797-2199cb82e5ed  26.0    Male     City
# 4998  7e8e9dab-a7af-4e1a-9401-eef18b57772b  53.0  Female     City
# 4999  12437469-887f-40d4-9bd0-d399bd8f77db  36.0  Female   Suburb
#
#      customer_segment                        transaction_id  \
# 0                High  d66461e5-ec3e-45c2-9975-2730e05b2613
# ...

# %%
df['Purchase_year']=df['date'].dt.year

# %%
df
# Out:
#                                customer_id   age  gender location  \
# 0     9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female     City
# 1     ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male     City
# 2     9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female     City
# 3     4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male     City
# 4     18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   Suburb
# ...                                    ...   ...     ...      ...
# 4995  5a1938c8-6983-49cb-bc15-abb5139fc5ba  24.0  Female     City
# 4996  a1ebd1a8-0028-4e14-a11c-b72d57ec8485  66.0  Female     City
# 4997  f4e8d429-f947-4340-9797-2199cb82e5ed  26.0    Male     City
# 4998  7e8e9dab-a7af-4e1a-9401-eef18b57772b  53.0  Female     City
# 4999  12437469-887f-40d4-9bd0-d399bd8f77db  36.0  Female   Suburb
#
#      customer_segment                        transaction_id  \
# 0                High  d66461e5-ec3e-45c2-9975-2730e05b2613
# ...

# %%
df=df.rename(columns={'Purchase_year':'purchase_year'})

# %%
df
# Out:
#                                customer_id   age  gender location  \
# 0     9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female     City
# 1     ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male     City
# 2     9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female     City
# 3     4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male     City
# 4     18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   Suburb
# ...                                    ...   ...     ...      ...
# 4995  5a1938c8-6983-49cb-bc15-abb5139fc5ba  24.0  Female     City
# 4996  a1ebd1a8-0028-4e14-a11c-b72d57ec8485  66.0  Female     City
# 4997  f4e8d429-f947-4340-9797-2199cb82e5ed  26.0    Male     City
# 4998  7e8e9dab-a7af-4e1a-9401-eef18b57772b  53.0  Female     City
# 4999  12437469-887f-40d4-9bd0-d399bd8f77db  36.0  Female   Suburb
#
#      customer_segment                        transaction_id  \
# 0                High  d66461e5-ec3e-45c2-9975-2730e05b2613
# ...

# %%
import sqlalchemy as sal
engine=sal.create_engine('mssql+pyodbc://SANTHOSH\\SQLEXPRESS/StudentsDB?driver=ODBC+Driver+17+for+SQL+Server')
conn=engine.connect()

# %%
df
# Out:
#                                Customer_ID   Age  Gender    Income Location  \
# 0     9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female  114415.0     City
# 1     ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male  160508.0     City
# 2     9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female   37669.0     City
# 3     4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male  147385.0     City
# 4     18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   92010.0   Suburb
# ...                                    ...   ...     ...       ...      ...
# 4995  5a1938c8-6983-49cb-bc15-abb5139fc5ba  24.0  Female   78465.0     City
# 4996  a1ebd1a8-0028-4e14-a11c-b72d57ec8485  66.0  Female  167745.0     City
# 4997  f4e8d429-f947-4340-9797-2199cb82e5ed  26.0    Male   43395.0     City
# 4998  7e8e9dab-a7af-4e1a-9401-eef18b57772b  53.0  Female  124162.0     City
# 4999  12437469-887f-40d4-9bd0-d399bd8f77db  36.0  Female  150704.0   Suburb
#
# ...

# %%
df.to_sql('df_customer_behavoir',con=conn,index=False,if_exists='replace')
# Out:
# 60

# %%
conn.close()

# %%
df
# Out:
#                                Customer_ID   Age  Gender    Income Location  \
# 0     9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female  114415.0     City
# 1     ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male  160508.0     City
# 2     9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female   37669.0     City
# 3     4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male  147385.0     City
# 4     18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   92010.0   Suburb
# ...                                    ...   ...     ...       ...      ...
# 4995  5a1938c8-6983-49cb-bc15-abb5139fc5ba  24.0  Female   78465.0     City
# 4996  a1ebd1a8-0028-4e14-a11c-b72d57ec8485  66.0  Female  167745.0     City
# 4997  f4e8d429-f947-4340-9797-2199cb82e5ed  26.0    Male   43395.0     City
# 4998  7e8e9dab-a7af-4e1a-9401-eef18b57772b  53.0  Female  124162.0     City
# 4999  12437469-887f-40d4-9bd0-d399bd8f77db  36.0  Female  150704.0   Suburb
#
# ...

# %%
df.columns=df.columns.str.lower()

# %%
df
# Out:
#                                customer_id   age  gender    income location  \
# 0     9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female  114415.0     City
# 1     ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male  160508.0     City
# 2     9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female   37669.0     City
# 3     4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male  147385.0     City
# 4     18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   92010.0   Suburb
# ...                                    ...   ...     ...       ...      ...
# 4995  5a1938c8-6983-49cb-bc15-abb5139fc5ba  24.0  Female   78465.0     City
# 4996  a1ebd1a8-0028-4e14-a11c-b72d57ec8485  66.0  Female  167745.0     City
# 4997  f4e8d429-f947-4340-9797-2199cb82e5ed  26.0    Male   43395.0     City
# 4998  7e8e9dab-a7af-4e1a-9401-eef18b57772b  53.0  Female  124162.0     City
# 4999  12437469-887f-40d4-9bd0-d399bd8f77db  36.0  Female  150704.0   Suburb
#
# ...

# %%
import sqlalchemy as sal
engine=sal.create_engine('mssql+pyodbc://SANTHOSH\\SQLEXPRESS/StudentsDB?driver=ODBC+Driver+17+for+SQL+Server')
conn=engine.connect()

# %%
df.to_sql('df_customers_behavoir',con=conn,index=False,if_exists='append')
# Out:
# 60

# %%
conn.close()

# %%
df
# Out:
#                                customer_id   age  gender    income location  \
# 0     9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female  114415.0     City
# 1     ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male  160508.0     City
# 2     9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female   37669.0     City
# 3     4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male  147385.0     City
# 4     18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   92010.0   Suburb
# ...                                    ...   ...     ...       ...      ...
# 4995  5a1938c8-6983-49cb-bc15-abb5139fc5ba  24.0  Female   78465.0     City
# 4996  a1ebd1a8-0028-4e14-a11c-b72d57ec8485  66.0  Female  167745.0     City
# 4997  f4e8d429-f947-4340-9797-2199cb82e5ed  26.0    Male   43395.0     City
# 4998  7e8e9dab-a7af-4e1a-9401-eef18b57772b  53.0  Female  124162.0     City
# 4999  12437469-887f-40d4-9bd0-d399bd8f77db  36.0  Female  150704.0   Suburb
#
# ...

# %%
df
# Out:
#                                customer_id   age  gender    income location  \
# 0     9a66bec2-57cf-4fb1-9fe6-79bae4fb4612  56.0  Female  114415.0     City
# 1     ef0d40d1-8e2d-4c64-b807-c982ce8865ac  69.0    Male  160508.0     City
# 2     9de2b87c-6554-4050-9456-9f56a923149d  46.0  Female   37669.0     City
# 3     4095a429-b32a-4eba-ba3d-3fa22591c0a0   NaN    Male  147385.0     City
# 4     18a218aa-3d30-4cf1-bc4a-890dcbb446d9  60.0  Female   92010.0   Suburb
# ...                                    ...   ...     ...       ...      ...
# 4995  5a1938c8-6983-49cb-bc15-abb5139fc5ba  24.0  Female   78465.0     City
# 4996  a1ebd1a8-0028-4e14-a11c-b72d57ec8485  66.0  Female  167745.0     City
# 4997  f4e8d429-f947-4340-9797-2199cb82e5ed  26.0    Male   43395.0     City
# 4998  7e8e9dab-a7af-4e1a-9401-eef18b57772b  53.0  Female  124162.0     City
# 4999  12437469-887f-40d4-9bd0-d399bd8f77db  36.0  Female  150704.0   Suburb
#
# ...

# %%
import sqlalchemy as sal
engine=sal.create_engine('mssql+pyodbc://SANTHOSH\\SQLEXPRESS/StudentsDB?driver=ODBC+Driver+17+for+SQL+Server')
conn=engine.connect()

# %%
df.to_sql('df_customers_behavior',con=conn,index=False,if_exists='append')
# Out:
# 60
